# %% [markdown]
# ### 앙상블(Ensemble)   : 결정 트리 기반 알고리즘
# * (1) Voting   :  서로 다른 알고리즘 가진 분류기를 결합, VotingClassifier
# * (2) Bagging  :  같은 유형의 알고리즘을 결합 , 데이터 샘플링시 서로 다르게 가져가면서 학습, RandomForest 가 대표적
#                   ( Bootstrapping Aggregation 의 줄임말)
# * (3) Boosting :  여러개의 분류기가 순차적으로 학습하면서 가중치를 부스팅한다, XGBoost(캐글대회 상위석권), LightGBM
# * (4) Stacking Ensemble: 위의 여러개의 개별적 모델들을 학습하여 예측한 데이터 세트를 사용하여 최종 메타모델이 학습 예측

# %% [markdown]
# ### 랜덤포레스트(RandomForest)
# * 결정트리 기반 알고리즘, 앙상블의 Bagging
# * CART(Classification And Regression Tree)를 사용해서 사용해 상관 관계가 없는 트리들로 포레스트를 구성(Leo Breiman의 논문)

# %%
### RandomForestClassificaier 예제
from sklearn.ensemble import RandomForestClassifier
from sklearn import metrics
from sklearn.model_selection import train_test_split
import pandas as pd
import numpy as np

# mushroom 데이터 셋
mr = pd.read_csv('mushroom.csv',header=None)
mr.shape  # (8124, 23)
mr
label = []
data = []

for row_index, row in mr.iterrows():
    label.append(row.iloc[0])
    
    row_data = []
    for v in row.iloc[1:]:
        row_data.append(ord(v))
    data.append(row_data)    

label 
data.shape
# Out:
# [[120,
#   115,
#   110,
#   116,
#   112,
#   102,
#   99,
#   110,
#   107,
#   101,
#   101,
#   115,
#   115,
#   119,
#   119,
#   112,
#   119,
#   111,
#   112,
#   107,
#   115,
#   117],
#  [120,
#   115,
#   121,
#   116,
#   97,
#   102,
#   99,
#   98,
#   107,
#   101,
#   99,
#   115,
#   115,
#   119,
#   119,
#   112,
#   119,
#   111,
#   112,
#   110,
#   110,
#   103],
#  [98,
#   115,
#   119,
#   116,
#   108,
#   102,
#   99,
#   98,
#   110,
#   101,
#   99,
#   115,
#   115,
#   119,
#   119,
#   112,
#   119,
#   111,
#   112,
#   110,
#   110,
#   109],
#  [120,
#   121,
#   119,
#   116,
#   112,
#   102,
#   99,
#   110,
#   110,
#   101,
#   101,
#   115,
#   115,
#   119,
#   119,
#   112,
#   119,
#   111,
#   112,
#   107,
#   115,
#   117],
#  [120,
#   115,
#   103,
#   102,
#   110,
#   102,
#   119,
#   98,
#   107,
#   116,
#   101,
#   115,
#   115,
#   119,
#   119,
#   112,
#   119,
#   111,
#   101,
#   110,
#   97,
#   103],
#  [120,
# ...
