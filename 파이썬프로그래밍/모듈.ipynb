# %% [markdown]
# ### 모듈
# #### : 함수나 변수 도는 클래스를 모아놓은 소스 파일

# %%
# def add(a,b):
#     c = a + b
#     return c

# def subtract(a,b):
#     c = a - b
#     return c

# def multiply(a,b):
#     c = a * b
#     return c

# def divide(a,b):
#     c = a / b
#     return c

# print('나는 모듈입니다')

# if __name__ == '__main__':
#     print(add(10,20))
#     print(subtract(30,10))

# %%
import calculator as cl     # claculator 모듈을 가져옴 이름을 cl 로 접근가능하게 함

if __name__ == '__main__':
    ret = cl.add(100,200)
    print(ret)

    ret = cl.subtract(300,100)
    print(ret)

    ret = cl.multiply(300,100)
    print(ret)

    ret = cl.divide(300,100)
    print(ret)

# # del add
# add(10,20)
# Out:
# 300
# 200
# 30000
# 3.0

# %%
# 패키지에서 일부 함수나 클래스를 가져오는 경우
from calculator import add
from calculator import add,subtract
from calculator import *

add(10,20)
# Out:
# 30

# %%
# first.py (import second) ,  second.py,  third.py

>> Python first.py    # __name__ 은 '__main__'  ,   secod.py의 __name__은 'second'
>> Python second.py    # __name__ 은 '__main__'  ,

# %%
# 클래스로 만든 모듈을 import하기
import calculator as cl     # claculator 모듈을 가져옴 이름을 cl 로 접근가능하게 함

if __name__ == '__main__':
    
    c = cl.Calc()          # 인스턴스 생성
    ret = c.add(100,200)   # 메서드 호출
    print(ret)
    
    print(c.a,c.b,c.c)     # 인스턴스 멤버 변수 접근
    
    ret = c.subtract(300,100)
    print(ret)

    ret = c.multiply(300,100)
    print(ret)

    ret = c.divide(300,100)
    print(ret)
# Out:
# 생성자가 호출됨
# 300
# 100 200 300
# 200
# 30000
# 3.0
